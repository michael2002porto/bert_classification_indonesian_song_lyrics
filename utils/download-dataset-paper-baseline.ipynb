# %%
# !conda install -y gdown
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.2.3             |     pyhd8ed1ab_0          48 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     conda-24.7.1               |  py310hff52083_0         940 KB  conda-forge
#     filelock-3.15.4            |     pyhd8ed1ab_0          17 KB  conda-forge
#     frozendict-2.4.4           |  py310hc51659f_0          48 KB  conda-forge
#     gdown-5.2.0                |     pyhd8ed1ab_0          21 KB  conda-forge
# ...

# %%
# !gdown 1a6fU04fdbjGijjkn3DaQjrM1viMfEGWn
# !gdown 1Q9W6w79eCTuZ-O8wgrCo0Qtc5YLRLwOR
# !gdown 1aAtyCT-SkzbDap5f1BeMB8l8weY5Xrr4

# !gdown 1-2DWBUxoovDdAFIfngQ5d3-uSGrdAhdP
# !gdown 1m6DN1jmLMwCuldZT2FrarzlZlDjyhAIi
# !gdown 1-6C3eNpieTxSbKa31-SnfHeOL8NChcdh

# !gdown 1-7_y6VU1G9JDPjGSpIR8fZOYcmBdXpcr
# !gdown 1W8caHzxHOhY1CngvuVnFbQA-HGE9FtO8
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1a6fU04fdbjGijjkn3DaQjrM1viMfEGWn
# To: /kaggle/working/arab_binary.csv
# 100%|████████████████████████████████████████| 732k/732k [00:00<00:00, 76.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Q9W6w79eCTuZ-O8wgrCo0Qtc5YLRLwOR
# To: /kaggle/working/eng_binary.csv
# 100%|███████████████████████████████████████| 1.67M/1.67M [00:00<00:00, 102MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1aAtyCT-SkzbDap5f1BeMB8l8weY5Xrr4
# To: /kaggle/working/german_binary.xlsx
# 100%|████████████████████████████████████████| 493k/493k [00:00<00:00, 77.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-2DWBUxoovDdAFIfngQ5d3-uSGrdAhdP
# To: /kaggle/working/indo_binary.csv
# 100%|██████████████████████████████████████| 74.5k/74.5k [00:00<00:00, 59.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1m6DN1jmLMwCuldZT2FrarzlZlDjyhAIi
# To: /kaggle/working/portuguese_binary.csv
# ...

# %%
# !gdown --id 1-J-hOVfIyJXI0aNj6GQ15A_YupFbGPq0

# %%
# !gdown --id 1-Bjh4Q00gsn6DPSqSFjWsc67eZQnQE5p

# %%
# !gdown --id 1-QTYDPh8VcSAIOcaWk03KgUtOmSxj1Dy
